# %% [markdown]
# <a href="https://colab.research.google.com/github/hundareshivani/LGMVIP-DataScienceTask/blob/main/Image%20to%20Pencil%20Sketch%20with%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**LET'S GROW MORE**
#
# ##**TASK 4 : Image to Pencil Sketch with Python**
#
# ###**AUTHOR** : **SHIVANI HUNDARE**

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
from google.colab.patches import cv2_imshow

import cv2

# %% [markdown]
# **IMPORTING IMAGE**

# %%
img = cv2.imread('/content/intermediate2.jpg', 1)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F15B33FD390>

# %% [markdown]
# **Converting an image into Gray Scale Image**

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F15B33E2490>

# %% [markdown]
# **Inverting the Image**

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F15B33F6350>

# %% [markdown]
# **Smoothing the Image**

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F15B33F6CD0>

# %% [markdown]
# **Obtaining the Final Sketch**

# %%
def dodgeV2(image, mask):
    return cv2.divide(image, 255-mask, scale=256)

# %%
def blend(front,back):
    result=front*255/(255-back)  
    result[result>255]=255 
    result[back==255]=255 
    return result

# %%
def render(img_rgb):
    img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
        
    #Applying gaussian blur to grayscale image
    img_blur = cv2.GaussianBlur(img_gray, (21,21), 0, 0)
    
    #Invert the blur image
    inverted_img = 255 - img_blur
    
    #Apply the dodgeV2 function
    img_blend = dodgeV2(img_gray,inverted_img)
    
    #Blend the image
    img_final = 1-blend(img_blend,img_gray)

    return img_final

# %% [markdown]
# **Final Output as Pencil Sketch**

# %%
plt.figure(figsize=(8,8))
plt.imshow(final_image, cmap="gray")
plt.title('Sketching of Image', fontsize=26)
plt.gca().axes.get_yaxis().set_visible(False)
plt.gca().axes.get_xaxis().set_visible(False)
plt.show()

# %% [markdown]
# **In This Task, We Demonstrated How To Convert Our Image Into a Pencil Sketch Using Computer Vision Techniques**

# %% [markdown]
# **THANKYOU**
